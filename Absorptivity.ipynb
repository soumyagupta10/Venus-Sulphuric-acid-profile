# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

# %%
x_low_bound= df['Column9']*9.86923e-6  
x_mid_bound = df['Column11']*9.86923e-6
x_high_bound = df['Column13']*9.86923e-6
y=df['Altitude']

plt.figure(figsize=(14,7))
plt.plot(x_low_bound,y)
plt.plot(x_mid_bound,y)
plt.plot(x_high_bound,y)

plt.xlabel('Pressure(atm)')
plt.ylabel('Altitude(kms)')
plt.title('Pressure Variation Profile')

plt.xlim(0,5)
plt.ylim(35,85)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e1aea1a4da04> in <module>
# ----> 1 x_low_bound= df['Column9']*9.86923e-6
#       2 x_mid_bound = df['Column11']*9.86923e-6
#       3 x_high_bound = df['Column13']*9.86923e-6
#       4 y=df['Altitude']
#       5
#
# NameError: name 'df' is not defined

# %% [markdown]
# WE see almost no difference in the value of pressure with different boundary conditions.

# %%
T_low_bound= df['Column15']
T_mid_bound= df['Column17']
T_high_bound= df['Column19']

plt.figure(figsize=(14,7))
plt.plot(T_low_bound,y)
plt.plot(T_mid_bound,y)
plt.plot(T_high_bound,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-214c97d260d5> in <module>
# ----> 1 T_low_bound= df['Column15']
#       2 T_mid_bound= df['Column17']
#       3 T_high_bound= df['Column19']
#       4
#       5 plt.figure(figsize=(14,7))
#
# NameError: name 'df' is not defined

# %%
DF1 = pd.read_csv("/content/PT1_lat(39-50N)SH.csv")
DF3=pd.read_csv("/content/PT3_(LAT-5.77-8.88)SH.csv")
DF4 = pd.read_csv("/content/PT4_(LAT- 19.44-19.69)SH.csv")
DF5=pd.read_csv("/content/PT5_(LAT- 33.71-33.88)SH.csv")
DF6 = pd.read_csv("/content/PT6_(LAT- 40.28-41.51)SH.csv")
DF7 = pd.read_csv("/content/PT7_(LAT- 68.92-82.96)SH.csv")
DF8 = pd.read_csv("/content/PT8_(LAT- 46.55-55.84)SH.csv")
DF2 = pd.read_csv("/content/PT2(lat-25.75-29)N.csv")

# %%
DF1['Altitude']= DF1['Column4']-6051.8
DF3['Altitude']= DF3['Column4']-6051.8
DF4['Altitude']= DF4['Column4']-6051.8
DF5['Altitude']= DF5['Column4']-6051.8
DF6['Altitude']= DF6['Column4']-6051.8
DF7['Altitude']= DF7['Column4']-6051.8
DF8['Altitude']= DF8['Column4']-6051.8
DF2['Altitude']= DF2['Column4']-6051.8

DF1_P_low_bound= DF1['Column9']*9.86923e-6  
DF3_P_low_bound= DF3['Column9']*9.86923e-6  
DF4_P_low_bound= DF4['Column9']*9.86923e-6  
DF5_P_low_bound= DF5['Column9']*9.86923e-6  
DF6_P_low_bound= DF6['Column9']*9.86923e-6  
DF7_P_low_bound= DF7['Column9']*9.86923e-6  
DF8_P_low_bound= DF8['Column9']*9.86923e-6  
DF2_P_low_bound= DF2['Column9']*9.86923e-6  

DF1_Y = DF1['Altitude']
DF3_Y = DF3['Altitude']
DF4_Y = DF4['Altitude']
DF5_Y = DF5['Altitude']
DF6_Y = DF6['Altitude']
DF7_Y = DF7['Altitude']
DF8_Y = DF8['Altitude']
DF2_Y = DF2['Altitude']

# %%
plt.figure(figsize=(14,9))
# plt.plot(DF1_P_low_bound,DF1_Y,label="LAT: 39$^\circ$-50$^\circ$")
plt.plot(DF3_P_low_bound,DF3_Y,label="LAT: 5.77$^\circ$-8.88$^\circ$")
#plt.plot(DF4_P_low_bound,DF4_Y,label="LAT: 19.44-19.69")
plt.plot(DF5_P_low_bound,DF5_Y,label="LAT: 33.71$^\circ$-33.88$^\circ$")
plt.plot(DF6_P_low_bound,DF6_Y,label="LAT: 40.28$^\circ$-41.51$^\circ$")
plt.plot(DF8_P_low_bound,DF8_Y,label="LAT: 46.55$^\circ$-55.84$^\circ$")
plt.plot(DF7_P_low_bound,DF7_Y,label="LAT: 68.92$^\circ$-82.96$^\circ$")

plt.xlabel('Pressure(atm)')
plt.ylabel('Altitude(kms)')
plt.title('Pressure Variation Profile of Southern Hemisphere at different latitudes')
plt.legend()

# %%
DF1_T_low_bound= DF1['Column15']
DF3_T_low_bound= DF3['Column15']
DF4_T_low_bound= DF4['Column15']
DF5_T_low_bound= DF5['Column15']
DF6_T_low_bound= DF6['Column15']
DF7_T_low_bound= DF7['Column15']
DF8_T_low_bound= DF8['Column15']
DF2_T_low_bound= DF2['Column15']

plt.figure(figsize=(14,9))
plt.plot(DF3_T_low_bound,DF3_Y,label="LAT: 5.77$^\circ$-8.88$^\circ$")
plt.plot(DF5_T_low_bound,DF5_Y,label="LAT: 33.71$^\circ$-33.88$^\circ$")
#plt.plot(DF1_T_low_bound,DF1_Y,label="LAT: 39-50")

#plt.plot(DF4_T_low_bound,DF4_Y)
plt.plot(DF6_T_low_bound,DF6_Y,label="LAT: 40.28$^\circ$-41.51$^\circ$")
plt.plot(DF8_T_low_bound,DF8_Y,label="LAT: 46.55$^\circ$-55.84$^\circ$")
plt.plot(DF7_T_low_bound,DF7_Y,label="LAT: 68.92$^\circ$-82.96$^\circ$")

plt.xlabel('Temperature (K)')
plt.ylabel('Altitude(kms)')
plt.title('Temperature Variation Profile of Southern Hemisphere at different latitudes')
plt.legend()

# %%
T5 = DF5['Column15'].to_numpy()
P5 = DF5_P_low_bound.to_numpy()
y5=  DF5['Altitude'].to_numpy()

T3 = DF3['Column15'].to_numpy()
P3 = DF3_P_low_bound.to_numpy()
y3=  DF3['Altitude'].to_numpy()

T7 = DF7['Column15'].to_numpy()
P7 = DF7_P_low_bound.to_numpy()
y7=  DF7['Altitude'].to_numpy()

T6 = DF6['Column15'].to_numpy()
P6 = DF6_P_low_bound.to_numpy()
y6=  DF6['Altitude'].to_numpy()

T2 = DF2['Column15'].to_numpy()
P2 = DF2_P_low_bound.to_numpy()
y2=  DF2['Altitude'].to_numpy()

# q is the number mixing ratio of the gasses
qco2 = 0.965
qn2 = 0.035
qso2 = 0.00015  

# In GHz given in .obs file of akatsuki
f=8.410932002 

#Creating empty array
alpha_co2_n2_5 = np.zeros(len(T5))
alpha_so2_5 = np.zeros(len(T5))
alpha_co2_n2_3 = np.zeros(len(T3))
alpha_so2_3 = np.zeros(len(T3))
alpha_co2_n2_7 = np.zeros(len(T7))
alpha_so2_7 = np.zeros(len(T7))
alpha_co2_n2_6 = np.zeros(len(T6))
alpha_so2_6 = np.zeros(len(T6))
alpha_co2_n2_2 = np.zeros(len(T2))
alpha_so2_2 = np.zeros(len(T2))

for i in range(0,len(T5)):
    alpha_co2_n2_5[i] = 1.15*10**8*(qco2**2 + 0.25*qco2*qn2+0.0054*qn2**2)*f**2*(P5[i]**2)*T5[i]**(-5)
    alpha_so2_5[i] = 4.3*10**6*f**2*P5[i]**(1.28)*T5[i]**(-2.91)*qso2

for i in range(0,len(T3)):
    alpha_co2_n2_3[i] = 1.15*10**8*(qco2**2 + 0.25*qco2*qn2+0.0054*qn2**2)*f**2*(P3[i]**2)*T3[i]**(-5)
    alpha_so2_3[i] = 4.3*10**6*f**2*P3[i]**(1.28)*T3[i]**(-2.91)*qso2

for i in range(0,len(T7)):
    alpha_co2_n2_7[i] = 1.15*10**8*(qco2**2 + 0.25*qco2*qn2+0.0054*qn2**2)*f**2*(P7[i]**2)*T7[i]**(-5)
    alpha_so2_7[i] = 4.3*10**6*f**2*P7[i]**(1.28)*T7[i]**(-2.91)*qso2

for i in range(0,len(T6)):
    alpha_co2_n2_6[i] = 1.15*10**8*(qco2**2 + 0.25*qco2*qn2+0.0054*qn2**2)*f**2*(P6[i]**2)*T6[i]**(-5)
    alpha_so2_6[i] = 4.3*10**6*f**2*P6[i]**(1.28)*T6[i]**(-2.91)*qso2

for i in range(0,len(T2)):
    alpha_co2_n2_2[i] = 1.15*10**8*(qco2**2 + 0.25*qco2*qn2+0.0054*qn2**2)*f**2*(P2[i]**2)*T2[i]**(-5)
    alpha_so2_2[i] = 4.3*10**6*f**2*P2[i]**(1.28)*T2[i]**(-2.91)*qso2   

plt.figure(figsize=(20,10))
plt.plot(alpha_co2_n2_3,y3,label=' LAT: 5.77$^\circ$-8.88$^\circ$') 
plt.plot(alpha_co2_n2_5,y5,label='LAT: 33.71$^\circ$-33.88$^\circ$')    
plt.plot(alpha_co2_n2_6,y6,label=' LAT:40.28$^\circ$-41.51$^\circ$') 
plt.plot(alpha_co2_n2_7,y7,label="LAT: 68.92$^\circ$-82.96$^\circ$") 

plt.ylabel('Altitude (km)')
plt.xlabel('Absorptivity (dB/km)')
plt.title("Absorption of $CO_2$ and $N_2$ at different latitudes")
plt.legend()
plt.show()



plt.figure(figsize=(20,10))
plt.plot(alpha_so2_3,y3,label='LAT: 5.77$^\circ$-8.88$^\circ$')
plt.plot(alpha_so2_5,y5,label='LAT: 33.71$^\circ$-33.88$^\circ$ ')
plt.plot(alpha_so2_6,y6,label='LAT:40.28$^\circ$-41.51$^\circ$')
plt.plot(alpha_so2_7,y7,label='LAT: 68.92$^\circ$-82.96$^\circ$ ')

plt.title("Absorption of $SO_2$ at different latitudes")
plt.ylabel('Altitude (km)')
plt.xlabel('Absorptivity (dB/km)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.plot(alpha_so2_7,y7,label='Absorptivity due to $SO_2$ ')
plt.plot(alpha_co2_n2_7,y7,label='Absorptivity due to $CO_2$-$N_2$ ') 

plt.ylabel('Altitude (km)')
plt.xlabel('Absorptivity (dB/km)')
plt.title("Absorption due to $CO_2$-$N_2$ and $SO_2$ at LAT: 68.92$^\circ$-82.96$^\circ$ SH")
plt.legend()

# %% [markdown]
# # These are 2020 RO  data

# %%
from numpy import diff
x = [.1, .2, .5, .6, .7, .8, .9]
y = [1, 2, 3, 4, 4, 5, 6]
dydx = diff(y)/diff(x)
print(dydx)
# Out:
# [10.          3.33333333 10.          0.         10.         10.        ]
# [10.0, 3.33333, 10.0, 0.0, 10.0, 10.0]

# %%
import numpy as np
from scipy.misc import derivative
temp= T3
press= DF3['Column9']
y= alpha_co2_n2_3

plt.plot(temp,y,'o--')

dydtemp = np.gradient(y,temp)
dydpress= np.gradient(y,press)

# %%
error = dydtemp * 10**(-2) + dydpress * 300

# %%
error
# Out:
# array([4.08677497e-08, 4.54407331e-08, 5.27513010e-08, 6.23607485e-08,
#        8.48718635e-08, 1.00520966e-07, 6.99576074e-08, 4.31470100e-08,
#        5.53256797e-08, 7.07880543e-08, 1.00916179e-07, 1.21643274e-07,
#        1.37152505e-07, 1.44756339e-07, 1.29437898e-07, 1.25854068e-07,
#        1.40280096e-07, 1.48800103e-07, 1.32135112e-07, 1.37252014e-07,
#        1.68499959e-07, 1.86705453e-07, 1.86171490e-07, 1.88145362e-07,
#        2.05045446e-07, 2.15262122e-07, 2.26557939e-07, 2.54586084e-07,
#        3.34042643e-07, 4.11725831e-07, 4.19483246e-07, 3.76643993e-07,
#        3.31166330e-07, 3.34320051e-07, 3.57150953e-07, 3.78247428e-07,
#        3.80110943e-07, 3.42174602e-07, 3.60752465e-07, 4.44558018e-07,
#        6.11382910e-07, 8.61800385e-07, 1.05671439e-06, 1.14390962e-06,
#        1.11769018e-06, 1.02191711e-06, 9.00427735e-07, 8.25087069e-07,
#        8.45384754e-07, 8.95847331e-07, 9.80952604e-07, 9.94317515e-07,
# ...

# %%
# %matplotlib inline
fig, ax = plt.subplots()
ax.errorbar(alpha_so2_3,y3, xerr =error,fmt='-o')
# Out:
#   File "<ipython-input-52-279beccb3adb>", line 4
#     xerr=error,fmt='-o')
#        ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

x = alpha_so2_3
y = y3
xerr = error



fig, ax = plt.subplots(figsize=(20,7))


ax.errorbar(x,y,
            xerr=xerr, ecolor='r')


ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_title('Line plot with error bars')


plt.show()
